# %% [markdown]
# <a href="https://colab.research.google.com/github/MFB-NTHU/Orientation/blob/main/Lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 這是讀取 CSV 檔

# %%
csv = read.csv('/content/XMacroCSV.csv')
head(csv)
# Out:
#   date      stock   overnight wage  cpi   hour  employment IPI
# 1 1995/1/26 6586.36 6.145     27891 78.62 185.4 9092       39.34
# 2 1995/2/28 6546.57 5.687     27257 78.28 170.0 9008       34.47
# 3 1995/3/31 6485.45 6.167     28056 78.39 204.7 8999       43.85
# 4 1995/4/29 6188.97 6.553     28068 79.54 187.0 9016       40.88
# 5 1995/5/31 5709.61 5.996     28429 79.39 206.9 9008       43.67
# 6 1995/6/30 5510.12 5.698     28244 80.25 197.1 8983       42.03

# %% [markdown]
# 檢查 csv 變數中的資料形態

# %%
class(csv)
# Out:
# [1] "data.frame"

# %%
library('readxl')

# %%
read_xlsx('/content/XMacro.xlsx')
# Out:
#     date       stock    overnight wage  cpi    hour  employment IPI
# 1   1995-01-26 6586.36  6.145     27891 78.62  185.4 9092       39.34
# 2   1995-02-28 6546.57  5.687     27257 78.28  170.0 9008       34.47
# 3   1995-03-31 6485.45  6.167     28056 78.39  204.7 8999       43.85
# 4   1995-04-29 6188.97  6.553     28068 79.54  187.0 9016       40.88
# 5   1995-05-31 5709.61  5.996     28429 79.39  206.9 9008       43.67
# 6   1995-06-30 5510.12  5.698     28244 80.25  197.1 8983       42.03
# 7   1995-07-31 5343.43  5.353     28479 79.78  200.9 9075       41.76
# 8   1995-08-31 4794.88  6.458     28707 79.98  207.2 9084       42.11
# 9   1995-09-30 5019.12  7.943     28735 80.46  191.5 9035       41.10
# 10  1995-10-30 5041.51  6.510     28886 80.26  187.3 9066       40.64
# 11  1995-11-30 4701.58  6.257     28944 80.58  197.9 9074       41.23
# 12  1995-12-30 4988.83  6.042     29152 80.55  194.9 9095       41.60
# ...
